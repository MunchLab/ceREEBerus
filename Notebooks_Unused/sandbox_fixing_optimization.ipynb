# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from cereeberus import Interleave, MapperGraph, Assignment
import cereeberus.data.ex_mappergraphs as ex_mg
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
mg1 = ex_mg.line(0, 20)
mg2 = ex_mg.torus(0, 2, 17, 18)

# %%
myInt = Interleave(mg1, mg2)
myInt.fit(verbose=True)
# Out:
# -
# Trying n = 2...
# n = 2, status = None
#
# -
# Trying n = 3...
# n = 3, status = None
#
# -
# Trying n = 6...
# n = 6, status = 1
#
# -
# Trying n = 4...
# n = 4, status = 1
#
# -
# Trying n = 3...
# n = 3, status = None
# 4

# %%
from cereeberus import ReebGraph
import numpy as np

# %%
# Example point cloud (you can replace this with your own)
points = np.random.rand(500, 3)  # 500 points in 3D

# Define a scalar function on these points — say, height (z-coordinate)
values = points[:, 2]

# Build and compute the Reeb graph
rg = ReebGraph()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 values = points[:, 2]
#       7 # Build and compute the Reeb graph
# ----> 8 rg = ReebGraph(values=values, coords=points)
#       9 rg.compute()
#
# TypeError: ReebGraph.__init__() got an unexpected keyword argument 'values'
