# %% [markdown]
# Generate Data

# %%
from sklearn.datasets import make_circles

number_of_points = 500

data, labels = make_circles(n_samples=number_of_points, factor=0.4, noise=0.05, random_state=0)


val = 0
pointcloud = []
while val < number_of_points:
    pointcloud.append(data[val])
    val += 1

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:, 0], data[:, 1], c=labels)
plt.axis('scaled');

# %% [markdown]
# Simple Mapper (no parameters except input graph)

# %%
from cereeberus import MapperGraph
import networkx as nx
import sklearn

graph = MapperGraph()
graph = MapperGraph.runmapper(pointcloud, "y", MapperGraph.cover(-1,1,7,.4), sklearn.cluster.DBSCAN(min_samples=2,eps=0.3).fit) 
graph.draw()
# Out:
# c:\Users\alexx\Documents\GitHub\ceREEBerus\cereeberus\cereeberus\reeb\mapper.py:17: SyntaxWarning: invalid escape sequence '\c'
#   - The values are integers in some range, [n_low, n_low+1, \cdots, n_high], although we consider the funciton values to be [\delta * n_low, \delta* (n_low+1), \cdots, \delta * n_high] for a stored delta

# %%
graph2 = MapperGraph.runmapper([(0.6, 0), (-0.1, 0.5)], "x", [(-1,0),(-0.5,0.5),(0,1)], "trivial")
graph2.draw()

# %%
from cereeberus import MapperGraph

graph3 = MapperGraph()
graph3 = MapperGraph.runmapper(pointcloud, "y", MapperGraph.cover(-6,6,12,.4), "trivial") 
graph3.draw()
