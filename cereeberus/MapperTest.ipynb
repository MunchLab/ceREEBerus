# %% [markdown]
# Generate Data

# %%
from sklearn.datasets import make_circles

number_of_points = 500

data, labels = make_circles(n_samples=number_of_points, factor=0.4, noise=0.05, random_state=0)


val = 0
pointcloud = []
while val < number_of_points:
    pointcloud.append(data[val])
    val += 1

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:, 0], data[:, 1], c=labels)
plt.axis('scaled');

# %% [markdown]
# Simple Mapper (no parameters except input graph)

# %%
from cereeberus import MapperGraph
import networkx as nx
import sklearn

graph = MapperGraph()
graph = MapperGraph.runmapper(pointcloud, "y", MapperGraph.cover(-1,1,7,40), sklearn.cluster.DBSCAN(min_samples=2,eps=0.3).fit) 
graph.draw()
# Out:
# [(-1.0571428571428572, -0.6571428571428571), (-0.7714285714285714, -0.37142857142857144), (-0.48571428571428565, -0.08571428571428572), (-0.19999999999999998, 0.19999999999999998), (0.08571428571428572, 0.48571428571428565), (0.37142857142857144, 0.7714285714285714), (0.6571428571428571, 1.0571428571428572)]

# %%
graph2 = MapperGraph.runmapper([(0.6, 0), (-0.1, 0.5)], "x", [(-1,0),(-0.5,0.5),(0,1)], "trivial")
graph2.draw()
