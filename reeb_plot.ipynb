# %%
from cereeberus.data import graphs

# %%
G = graphs.reeb_torus()

# %%
from cereeberus import reeb
import matplotlib

# %%
reeb_class = reeb

# %%
pos = reeb_class.reeb.node_position(reeb, G=G)
reeb_class.reeb.plot_reeb(reeb, G, pos)
